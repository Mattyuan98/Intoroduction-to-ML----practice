# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#设置颜色
r_hex = '#dc2624' #red
dt_hex = '#2b4750' # dark teal
g_hex = '#649E7D'#green

# %%
#在图中添加基本元素-文字
plt.figure()
plt.text(0.5,0.5,'figure',ha = 'center',va = 'center',size = 20, alpha = .5)
# 第一、二个指横纵坐标，ha,va是横向纵向位置，size是字体大小，alpha字体透明度（0.5为半透明）
plt.xticks([]),plt.yticks([])
plt.show()

# %%
#子图
plt.subplot(2,1,1)
plt.xticks([]),plt.yticks([])
plt.text(0.5,0.5,'subplot(2,1,1)',ha = 'center',va='center',size = 20, alpha = 0.5)

plt.subplot(2,1,2)
plt.xticks([]),plt.yticks([])
plt.text(0.5,0.5,'subplot(2,1,2)',ha = 'center',va='center',size = 20, alpha = 0.5)

plt.show()

# %%
plt.subplot(1,2,1)
plt.xticks([]),plt.yticks([])
plt.text(0.5,0.5,'subplot(1,2,1)',ha = 'center',va='center',size = 20, alpha = 0.5)

plt.subplot(1,2,2)
plt.xticks([]),plt.yticks([])
plt.text(0.5,0.5,'subplot(1,2,2)',ha = 'center',va='center',size = 20, alpha = 0.5)

plt.show()

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 2)

for i,ax in enumerate(axes.flat):
    ax.set(xticks=[], yticks = [])
    s = 'subplot(2,2,' + str(i) + ')'
    ax.text(0.5,0.5, s, ha ='center',va = 'center',size = 20, alpha = 0.5)
    
plt.show()
